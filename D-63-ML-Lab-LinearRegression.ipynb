# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.axes as ax

# %%
data = pd.read_csv('LR_SR.csv')
data.shape
# Out:
# (700, 2)

# %%
data
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [700 rows x 2 columns]

# %%
data.describe()
# Out:
#                  x           y
# count   700.000000  699.000000
# mean     54.985939   49.939869
# std     134.681703   29.109217
# min       0.000000   -3.839981
# 25%      25.000000   24.929968
# 50%      49.000000   48.973020
# 75%      75.000000   74.929911
# max    3530.157369  108.871618

# %%
data.isnull
# Out:
# <bound method DataFrame.isnull of         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [700 rows x 2 columns]>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       700 non-null    float64
#  1   y       699 non-null    float64
# dtypes: float64(2)
# memory usage: 11.1 KB

# %%
data.isnull().sum()
# Out:
# x    0
# y    1
# dtype: int64

# %%
data=data.dropna()

dx=data.drop(['y'],axis=1)
dx.shape

target_y=data.drop(['x'],axis=1)
target_y.shape
# Out:
# (699, 1)

# %%
data
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [699 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 699 entries, 0 to 699
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       699 non-null    float64
#  1   y       699 non-null    float64
# dtypes: float64(2)
# memory usage: 16.4 KB

# %%
data.isnull().sum()
# Out:
# x    0
# y    0
# dtype: int64

# %%
target_y
# Out:
#              y
# 0    21.549452
# 1    47.464463
# 2    17.218656
# 3    36.586398
# 4    87.288984
# ..         ...
# 695  58.595006
# 696  94.625094
# 697  88.603770
# 698  63.648685
# 699  94.975266
#
# [699 rows x 1 columns]

# %%
dx
# Out:
#         x
# 0    24.0
# 1    50.0
# 2    15.0
# 3    38.0
# 4    87.0
# ..    ...
# 695  58.0
# 696  93.0
# 697  82.0
# 698  66.0
# 699  97.0
#
# [699 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(dx,target_y,test_size=0.2)

# %%
len(x_train)
# Out:
# 559

# %%
len(y_train)
# Out:
# 559

# %%
x_test.shape
# Out:
# (140, 1)

# %%
y_test.shape
# Out:
# (140, 1)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict_train1=reg.predict(x_train)
y_predict_train1
# Out:
# array([[ 75.02701518],
#        [ 89.06262505],
#        [ 52.9710568 ],
#        [ 10.86422717],
#        [ 93.0727993 ],
#        [ 28.9100113 ],
#        [ 47.95833899],
#        [ 23.89729349],
#        [ 48.96088255],
#        [ 75.02701518],
#        [ 25.90238061],
#        [ 91.06771218],
#        [ 48.96088255],
#        [ 81.04227655],
#        [ 70.01429736],
#        [ 79.03718943],
#        [ 20.8896628 ],
#        [ 18.88457567],
#        [ 15.87694499],
#        [ 59.98886174],
#        [ 16.87948855],
#        [ 84.04990724],
#        [ 85.0524508 ],
#        [ 94.07534286],
#        [ 20.8896628 ],
#        [ 65.00157955],
#        [100.09060424],
#        [ 90.06516861],
#        [  4.8489658 ],
#        [ 65.00157955],
#        [  2.84387867],
#        [ 94.07534286],
#        [ 57.98377461],
#        [ 95.07788643],
#        [ 51.96851324],
#        [ 48.96088255],
#        [ 48.96088255],
#        [ -0.16375201],
#        [ 46.95579542],
#        [ -0.16375201],
# ...

# %%
plt.scatter(x_train,y_train,color='blue')
plt.plot(x_train,y_predict_train1,color='white')
plt.xlabel("X_Train")
plt.ylabel("y_Predict_Train1")
plt.show()

# %%
model.score(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9548/3730961691.py in <module>
# ----> 1 model.score(x_train,y_train)
#
# NameError: name 'model' is not defined

# %%
y_predict_test1=reg.predict(x_test)
y_predict_test1
# Out:
# array([[ 62.99649242],
#        [ 54.97614392],
#        [ 88.06008149],
#        [ 77.0321023 ],
#        [ 90.06516861],
#        [  7.85659649],
#        [ 49.96342611],
#        [ 42.94562117],
#        [ -0.16375201],
#        [ 89.06262505],
#        [ 61.99394886],
#        [ 53.97360036],
#        [ 51.96851324],
#        [ 15.87694499],
#        [ 87.05753793],
#        [  7.85659649],
#        [ 85.0524508 ],
#        [ 47.95833899],
#        [ 35.92781624],
#        [ 52.9710568 ],
#        [ 87.05753793],
#        [ 39.93799049],
#        [ 25.90238061],
#        [ 62.99649242],
#        [ 61.99394886],
#        [ 53.97360036],
#        [ 87.05753793],
#        [ 36.9303598 ],
#        [ 89.06262505],
#        [ 18.88457567],
#        [ 74.02447161],
#        [ 50.96596967],
#        [  4.8489658 ],
#        [ 30.91509842],
#        [ 22.89474992],
#        [  8.85914005],
#        [ 61.99394886],
#        [ 60.9914053 ],
#        [  7.85659649],
#        [ 37.93290336],
# ...

# %%
plt.scatter(x_test,y_test,color='green')
plt.plot(x_test,y_predict_test1,color='blue')
plt.xlabel("X_Test")
plt.ylabel("y_Predict_Test1")
plt.show()

# %%
x_test
# Out:
#         x
# 635  63.0
# 95   55.0
# 305  88.0
# 91   77.0
# 354  90.0
# ..    ...
# 575  15.0
# 295  55.0
# 444  75.0
# 373  10.0
# 180  26.0
#
# [140 rows x 1 columns]

# %%
c=reg.intercept_

# %%
c
# Out:
# array([-0.16375201])

# %%
m=reg.coef_
m
# Out:
# array([[1.00254356]])

# %%
y_predict_train = c + m*x_train
y_predict_train
# Out:
#              x
# 56   75.027015
# 456  89.062625
# 164  52.971057
# 253  10.864227
# 35   93.072799
# ..         ...
# 378  31.917642
# 551  49.963426
# 495  60.991405
# 343  93.072799
# 407  47.958339
#
# [559 rows x 1 columns]
