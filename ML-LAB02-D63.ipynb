# %% [markdown]
# # --to study and apply data preprocessing techniques on given dataset
# --prepare a titanic and heart disease datset for training with machine learning algorithm by applying suitable datprocessing techniques
# tasks :
#   --perform basic EDA using functions like head tail desc shift
#   --identify AND handle missing values
#   --check for duplicate and handle
#   --apply data encoding techniqwues on suitable attributes
#   --applu multivariate bi uni
#   --split the dataset in 80:20 ratio for traINING AND TESTING

# %%
import pandas as pd

# %%
df = pd.read_excel('titanic.xlsx')
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#df.drop("Pclass",axis=1,inplace=True)

# %%
df.drop("Cabin",axis=1,inplace=True)

# %%
df.drop("Name",axis=1,inplace=True)

# %%
df.drop("Embarked",axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 62.8+ KB

# %%
df.drop("Parch",axis=1,inplace=True)

# %%
df.drop("SibSp",axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   Ticket       891 non-null    object
#  6   Fare         891 non-null    float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 48.9+ KB

# %%
df.drop("PassengerId",axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   Ticket    891 non-null    object
#  5   Fare      891 non-null    float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 41.9+ KB

# %%
df
# Out:
#      Survived  Pclass     Sex   Age            Ticket     Fare
# 0           0       3    male  22.0         A/5 21171   7.2500
# 1           1       1  female  38.0          PC 17599  71.2833
# 2           1       3  female  26.0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0            113803  53.1000
# 4           0       3    male  35.0            373450   8.0500
# ..        ...     ...     ...   ...               ...      ...
# 886         0       2    male  27.0            211536  13.0000
# 887         1       1  female  19.0            112053  30.0000
# 888         0       3  female   NaN        W./C. 6607  23.4500
# 889         1       1    male  26.0            111369  30.0000
# 890         0       3    male  32.0            370376   7.7500
#
# [891 rows x 6 columns]

# %%
df.drop("Ticket",axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age     Fare
# 0           0       3    male  22.0   7.2500
# 1           1       1  female  38.0  71.2833
# 2           1       3  female  26.0   7.9250
# 3           1       1  female  35.0  53.1000
# 4           0       3    male  35.0   8.0500
# ..        ...     ...     ...   ...      ...
# 886         0       2    male  27.0  13.0000
# 887         1       1  female  19.0  30.0000
# 888         0       3  female   NaN  23.4500
# 889         1       1    male  26.0  30.0000
# 890         0       3    male  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
df_new = df.copy()

df_new
# Out:
#      Survived  Pclass     Sex   Age     Fare
# 0           0       3    male  22.0   7.2500
# 1           1       1  female  38.0  71.2833
# 2           1       3  female  26.0   7.9250
# 3           1       1  female  35.0  53.1000
# 4           0       3    male  35.0   8.0500
# ..        ...     ...     ...   ...      ...
# 886         0       2    male  27.0  13.0000
# 887         1       1  female  19.0  30.0000
# 888         0       3  female   NaN  23.4500
# 889         1       1    male  26.0  30.0000
# 890         0       3    male  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
df
# Out:
#      Survived  Pclass     Sex   Age     Fare
# 0           0       3    male  22.0   7.2500
# 1           1       1  female  38.0  71.2833
# 2           1       3  female  26.0   7.9250
# 3           1       1  female  35.0  53.1000
# 4           0       3    male  35.0   8.0500
# ..        ...     ...     ...   ...      ...
# 886         0       2    male  27.0  13.0000
# 887         1       1  female  19.0  30.0000
# 888         0       3  female   NaN  23.4500
# 889         1       1    male  26.0  30.0000
# 890         0       3    male  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
#survived is dependent (variable) on the various different independent factors i.e age gender pclass

# %%
target=df.Survived

# %%
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df_new.drop("Survived",axis=1,inplace=True)

# %%
df_new
# Out:
#      Pclass     Sex   Age     Fare
# 0         3    male  22.0   7.2500
# 1         1  female  38.0  71.2833
# 2         3  female  26.0   7.9250
# 3         1  female  35.0  53.1000
# 4         3    male  35.0   8.0500
# ..      ...     ...   ...      ...
# 886       2    male  27.0  13.0000
# 887       1  female  19.0  30.0000
# 888       3  female   NaN  23.4500
# 889       1    male  26.0  30.0000
# 890       3    male  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
#input to the machine will be independent variables and output-target

# %%
#input and output will train the ML model and on the basis of it hypothesis will be generated by it

# %%
df_new.isnull()
# Out:
#      Pclass    Sex    Age   Fare
# 0     False  False  False  False
# 1     False  False  False  False
# 2     False  False  False  False
# 3     False  False  False  False
# 4     False  False  False  False
# ..      ...    ...    ...    ...
# 886   False  False  False  False
# 887   False  False  False  False
# 888   False  False   True  False
# 889   False  False  False  False
# 890   False  False  False  False
#
# [891 rows x 4 columns]

# %%
df_new.isnull().sum()
# Out:
# Pclass      0
# Sex         0
# Age       177
# Fare        0
# dtype: int64

# %%
#df_new=df_new[~df_new.Age.isnull()].copy()

# %%
#frst approach should be to fill missing values with any logical measure which will not affect the our prediction

# %%
df_new.Age.mean()
# Out:
# 29.69911764705882

# %%
df_new["Age"].fillna(df_new.Age.mean(), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   Fare      891 non-null    float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 34.9+ KB

# %%
#df_new["Age"].fillna(, inplace=True)

# %%
df_new
# Out:
#      Pclass     Sex        Age     Fare
# 0         3    male  22.000000   7.2500
# 1         1  female  38.000000  71.2833
# 2         3  female  26.000000   7.9250
# 3         1  female  35.000000  53.1000
# 4         3    male  35.000000   8.0500
# ..      ...     ...        ...      ...
# 886       2    male  27.000000  13.0000
# 887       1  female  19.000000  30.0000
# 888       3  female  29.699118  23.4500
# 889       1    male  26.000000  30.0000
# 890       3    male  32.000000   7.7500
#
# [891 rows x 4 columns]

# %%
df_new.isnull().sum()
# Out:
# Pclass    0
# Sex       0
# Age       0
# Fare      0
# dtype: int64

# %%
df_new['Sex'].replace(['male', 'female','other'],[0, 1,2],inplace=True)

# %%
df_new
# Out:
#      Pclass  Sex        Age     Fare
# 0         3    0  22.000000   7.2500
# 1         1    1  38.000000  71.2833
# 2         3    1  26.000000   7.9250
# 3         1    1  35.000000  53.1000
# 4         3    0  35.000000   8.0500
# ..      ...  ...        ...      ...
# 886       2    0  27.000000  13.0000
# 887       1    1  19.000000  30.0000
# 888       3    1  29.699118  23.4500
# 889       1    0  26.000000  30.0000
# 890       3    0  32.000000   7.7500
#
# [891 rows x 4 columns]

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  891 non-null    int64
#  1   Sex     891 non-null    int64
#  2   Age     891 non-null    float64
#  3   Fare    891 non-null    float64
# dtypes: float64(2), int64(2)
# memory usage: 28.0 KB

# %%
df_new.shape
# Out:
# (891, 4)

# %%
target.shape
# Out:
# (891,)

# %%
df_new.isnull().sum()
# Out:
# Pclass    0
# Sex       0
# Age       0
# Fare      0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(df_new,target,test_size=0.2)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 170 to 198
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  712 non-null    int64
#  1   Sex     712 non-null    int64
#  2   Age     712 non-null    float64
#  3   Fare    712 non-null    float64
# dtypes: float64(2), int64(2)
# memory usage: 27.8 KB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179 entries, 382 to 110
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  179 non-null    int64
#  1   Sex     179 non-null    int64
#  2   Age     179 non-null    float64
#  3   Fare    179 non-null    float64
# dtypes: float64(2), int64(2)
# memory usage: 7.0 KB

# %%
Y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 712 entries, 170 to 198
# Series name: Survived
# Non-Null Count  Dtype
# --------------  -----
# 712 non-null    int64
# dtypes: int64(1)
# memory usage: 11.1 KB

# %%
Y_test.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 179 entries, 382 to 110
# Series name: Survived
# Non-Null Count  Dtype
# --------------  -----
# 179 non-null    int64
# dtypes: int64(1)
# memory usage: 2.8 KB

# %%
from sklearn import tree

# %%
df_new
# Out:
#      Pclass  Sex        Age     Fare
# 0         3    0  22.000000   7.2500
# 1         1    1  38.000000  71.2833
# 2         3    1  26.000000   7.9250
# 3         1    1  35.000000  53.1000
# 4         3    0  35.000000   8.0500
# ..      ...  ...        ...      ...
# 886       2    0  27.000000  13.0000
# 887       1    1  19.000000  30.0000
# 888       3    1  29.699118  23.4500
# 889       1    0  26.000000  30.0000
# 890       3    0  32.000000   7.7500
#
# [891 rows x 4 columns]

# %%
df
# Out:
#      Survived  Pclass  Sex   Age     Fare
# 0           0       3    0  22.0   7.2500
# 1           1       1    1  38.0  71.2833
# 2           1       3    1  26.0   7.9250
# 3           1       1    1  35.0  53.1000
# 4           0       3    0  35.0   8.0500
# ..        ...     ...  ...   ...      ...
# 886         0       2    0  27.0  13.0000
# 887         1       1    1  19.0  30.0000
# 888         0       3    1   NaN  23.4500
# 889         1       1    0  26.0  30.0000
# 890         0       3    0  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
model = tree.DecisionTreeClassifier()

# %%
model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_train,Y_train)
# Out:
# 0.9789325842696629

# %%
model.predict([[3,1,34.98,700.98]])
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
model.score(X_test,Y_test)
# Out:
# 0.6871508379888268

# %%
model.predict([[4,0,98.08,60.86]])
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)
